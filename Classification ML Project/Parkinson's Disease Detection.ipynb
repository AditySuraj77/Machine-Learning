# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
pd.set_option('display.max_columns', None)

# %%
# load data
parkinson_data = pd.read_csv('parkinsons.csv')
parkinson_data.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374
# 1           0.00008   0.00465   0.00696     0.01394       0.06134
# 2           0.00009   0.00544   0.00781     0.01633       0.05233
# 3           0.00009   0.00502   0.00698     0.01505       0.05492
# 4           0.00011   0.00655   0.00908     0.01966       0.06425
#
#    MDVP:Shimmer(dB)  Shimmer:APQ3  Shimmer:APQ5  MDVP:APQ  Shimmer:DDA  \
# ...

# %%
parkinson_data.shape
# Out:
# (195, 24)

# %%
parkinson_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %%
parkinson_data.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
parkinson_data.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %%
parkinson_data.groupby('status').mean()
# Out:
#         MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# status
# 0        181.937771    223.636750    145.207292        0.003866
# 1        145.180762    188.441463    106.893558        0.006989
#
#         MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# status
# 0               0.000023  0.001925  0.002056    0.005776      0.017615
# 1               0.000051  0.003757  0.003900    0.011273      0.033658
#
#         MDVP:Shimmer(dB)  Shimmer:APQ3  Shimmer:APQ5  MDVP:APQ  Shimmer:DDA  \
# status
# 0               0.162958      0.009504      0.010509  0.013305     0.028511
# 1               0.321204      0.017676      0.020285  0.027600     0.053027
#
#              NHR        HNR      RPDE       DFA   spread1   spread2        D2  \
# status
# 0       0.011483  24.678750  0.442552  0.695716 -6.759264  0.160292  2.154491
# 1       0.029211  20.974048  0.516816  0.725408 -5.333420  0.248133  2.456058
#
#              PPE
# status
# 0       0.123017
# ...

# %%
parkinson_data.status.value_counts()
# Out:
# 1    147
# 0     48
# Name: status, dtype: int64

# %% [markdown]
# # 1 ---> Parkinson Disease
# # 0 ---> Healthy

# %%
# Separate the data and label
X = parkinson_data.drop(columns=['name', 'status'], axis=1)
Y = parkinson_data['status']

# %%
print(X)
print(Y)
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0        119.992       157.302        74.997         0.00784
# 1        122.400       148.650       113.819         0.00968
# 2        116.682       131.111       111.555         0.01050
# 3        116.676       137.871       111.366         0.00997
# 4        116.014       141.781       110.655         0.01284
# ..           ...           ...           ...             ...
# 190      174.188       230.978        94.261         0.00459
# 191      209.516       253.017        89.488         0.00564
# 192      174.688       240.005        74.287         0.01360
# 193      198.764       396.961        74.904         0.00740
# 194      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0             0.00007   0.00370   0.00554     0.01109       0.04374
# 1             0.00008   0.00465   0.00696     0.01394       0.06134
# ...

# %% [markdown]
# ### Split data into train & test

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y, test_size=0.1, random_state=2)

# %%
print(X.shape,X_train.shape,X_test.shape)
print(Y.shape,Y_train.shape,Y_test.shape)
# Out:
# (195, 22) (175, 22) (20, 22)
# (195,) (175,) (20,)

# %% [markdown]
# ### Scale the data using Standardization

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
print(X_train)
print(X_test)
# Out:
# [[-0.0958292  -0.45761067  0.3506123  ... -0.75251389 -0.22367954
#   -1.00898164]
#  [ 1.13640163  0.36767264 -0.69610863 ... -0.11814507  0.22048682
#   -0.19206898]
#  [-0.86963504 -0.79928946 -0.25979718 ... -0.32744932 -0.70393396
#   -0.25242382]
#  ...
#  [-0.86958654 -0.6537697  -0.13540295 ...  1.27560661 -0.45831193
#   -0.20148699]
#  [-0.33400165  0.21130399 -0.7650968  ... -0.15630331 -0.45697845
#    0.31151806]
#  [ 1.00943452  0.21321784 -0.59369274 ... -0.70622533  1.27220311
#   -0.03900426]]
# [[-1.63941557e+00 -9.59430187e-01 -7.44600147e-01 -2.54738340e-01
#    4.51166245e-01 -2.75821641e-01 -7.03648547e-02 -2.74787459e-01
#   -4.51654424e-01 -4.49404017e-01 -4.91983397e-01 -3.83902308e-01
#   -3.16760931e-01 -4.91983119e-01 -3.39476160e-01 -1.47842622e-01
#    1.08902114e+00  1.05726879e+00  4.01479696e-01  2.02161963e+00
#    5.84443785e-02  4.78997201e-01]
#  [-1.33783232e+00 -9.20963922e-01 -7.11531623e-01  8.07383098e-01
# ...

# %% [markdown]
# # Model Training
#
# ### SVC ( Support Vector Classifier)

# %%
classifier = svm.SVC(kernel='linear')

# %%
classifier.fit(X_train,Y_train)
# Out:
# SVC(kernel='linear')

# %% [markdown]
# ### Model Evalution

# %%
X_train_prediction = classifier.predict(X_train)  # Accuracy on training data
training_data_accuracy = accuracy_score(X_train_prediction,Y_train)
print('Accuracy on training data = ', training_data_accuracy)
# Out:
# Accuracy on training data =  0.8742857142857143

# %%
X_test_prediction = classifier.predict(X_test) # Accuracy on test data
test_data_accuracy = accuracy_score(X_test_prediction,Y_test)
print('Accuracy on test data = ', test_data_accuracy)
# Out:
# Accuracy on test data =  0.9

# %%
#user_input = (115.32200,135.73800,107.80200,0.00619,0.00005,0.00352,0.00329,0.01057,0.03273,0.32500,0.01644,0.01722,0.02931,0.04933,0.02810,19.38800,0.577802,0.684373,-5.283009,0.226528,2.442906,0.238281)

user_input = (240.30100,245.13500,219.78300,0.00517,0.00002,0.00316,0.00283,0.00949,0.02018,0.21200,0.01176,0.01191,0.01344,0.03529,0.00965,21.02000,0.371837,0.646167,-7.169701,0.073298,2.266432,0.100881
)
user_input_numpy_asarray = np.asarray(user_input)

reshaped_numpy_asarry = user_input_numpy_asarray.reshape(1,-1)

scale_data = scaler.transform(reshaped_numpy_asarry)

prediction = classifier.predict(scale_data)
print(prediction)


if (prediction[0] == 1):
    print('The Person has Parkinson Disease')
else:
    print('Person is Healthy')
# Out:
# [0]
# Person is Healthy
# C:\Users\user.LAPTOP\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
